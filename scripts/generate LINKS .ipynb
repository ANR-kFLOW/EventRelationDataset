# %%
import pandas as pd
import numpy as np
import os
os.chdir('/content/drive/MyDrive/kFLOW/EKAW 2022/TML generation tryouts /well aligned rows')

# %%
df = pd.read_csv('enable.csv')
df.columns[6]
# Out:
# 'annotation '

# %%
df

# %%
df = pd.read_csv('enable.csv')

m = df[df.columns[6]] == 1

a=df.loc[m, [df.columns[7], df.columns[2],df.columns[4]]] 

#df.to_csv('/content/drive/MyDrive/kFLOW/EKAW 2022/TML generation tryouts /well aligned rows/'+csvFile)

# %%
a
# Out:
#                Doc name   eid1  eid2     rel
# 1          wsj_0376.tml    e46  e104  enable
# 27         wsj_0159.tml    e29   e34  enable
# 40         wsj_0073.tml  e2000    e8  enable
# 49         wsj_0073.tml  e2000    e9  enable
# 81         wsj_0542.tml    e11   e17  enable
# 86         wsj_0798.tml    e41   e17  enable
# 91         wsj_0713.tml     e5    e9  enable
# 168        wsj_0745.tml   e139  e142  enable
# 180        wsj_0745.tml   e139  e143  enable
# 214  WSJ910225-0066.tml    e18   e25  enable
# 301  WSJ900813-0157.tml    e11   e15  enable

# %%
np.savetxt(r'/content/drive/MyDrive/kFLOW/BERT paper replication/EventCausalityIdentification-master/EventCausalityIdentification-master/Timebankenablelinks.txt', a.values, fmt='%s', delimiter='\t')

# %%
len(os.listdir('/content/drive/MyDrive/kFLOW/BERT paper replication/datasets/EventCausality dataset/TCR-master/TemporalPart'))
# Out:
# 25
