# %%
# !pip3 install --upgrade pip
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 13.7 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.1.1
#     Uninstalling pip-22.1.1:
#       Successfully uninstalled pip-22.1.1
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
pip install --upgrade pip setuptools wheel
# Out:
# ...
#   Using cached pip-22.2.1-py3-none-any.whl (2.0 MB)
# ...
#   Using cached setuptools-63.3.0-py3-none-any.whl (1.2 MB)
# ...
#   Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 20.2.3
#     Uninstalling pip-20.2.3:
#       Successfully uninstalled pip-20.2.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 49.2.1
#     Uninstalling setuptools-49.2.1:
#       Successfully uninstalled setuptools-49.2.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 33.5 MB/s eta 0:00:0000:010:01
# ...
#   Using cached pytz-2022.1-py2.py3-none-any.whl (503 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 20.8 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv (r'/Users/youssrarebboud/Desktop/PhD/datasets/EventRela.csv')

# %%
df['relation'][100].split('|')[0]
# Out:
# 'True/Related/Temporality.Before/Relative/Previous/After'

# %%
newdata = pd.DataFrame(columns = df.columns.tolist()+['rel1','rel2','rel3'])

# %%
len(newdata.columns)
# Out:
# 11

# %%
for index, row in df.iterrows():
    tmp=row['relation'].split('|')
    relations=[rel for rel in tmp if "True/Related" in rel and not 'Vague' in rel]
    
    if relations:
        newrow=row.tolist()+relations
        while len(newrow)<len(newdata.columns):
            newrow.append(None)
        
        newdata.loc[len(newdata)] = newrow

# %%
newdata = newdata.drop('relation', axis=1)

# %%
newdata
# Out:
#                        evnt1id  \
# 0     AFP_ENG_20100414.0615-E5
# 1     AFP_ENG_20100414.0615-E5
# 2     AFP_ENG_20100414.0615-E5
# 3     AFP_ENG_20100414.0615-E5
# 4     AFP_ENG_20100414.0615-E5
# ..                         ...
# 443  AFP_ENG_20030509.0345-EV1
# 444  AFP_ENG_20030509.0345-EV1
# 445  AFP_ENG_20030509.0345-EV1
# 446  AFP_ENG_20030509.0345-EV2
# 447  AFP_ENG_20030509.0345-EV2
#
#                                              evnt1text  \
# 0    parole(contexts: A former militant of the Fren...
# 1    parole(contexts: A former militant of the Fren...
# 2    parole(contexts: A former militant of the Fren...
# 3    parole(contexts: A former militant of the Fren...
# 4    parole(contexts: A former militant of the Fren...
# ..                                                 ...
# 443   A ground-breaking British budget cinema chain...
# 444   A ground-breaking British budget cinema chain...
# 445   A ground-breaking British budget cinema chain...
# ...

# %%
newdata.to_csv('newdata.csv', sep='\t')

# %%
h
# Out:
# ['EventError/    /    /    /    /    ']

# %%
data = data.append(row)
# Out:
# /var/folders/yn/342mzbk93q54f6l4fr2xyc780000gn/T/ipykernel_15817/4153375629.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(row)

# %%
data.append({'evnt1id':1,'evnt1text':1,'evnt1type':1,'evnt2id':1,'evnt2text':1,'evnt2type':1,'relation':1,'docname':1}, ignore_index = True)
# Out:
# /var/folders/yn/342mzbk93q54f6l4fr2xyc780000gn/T/ipykernel_15817/3123928164.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data.append({'evnt1id':1,'evnt1text':1,'evnt1type':1,'evnt2id':1,'evnt2text':1,'evnt2type':1,'relation':1,'docname':1}, ignore_index = True)
#                     evnt1id  \
# 0  AFP_ENG_20100414.0615-E1
# 1                         1
#
#                                            evnt1text evnt1type  \
# 0  killer(contexts: French far - left killer leav...  Life_Die
# 1                                                  1         1
#
#                     evnt2id  \
# 0  AFP_ENG_20100414.0615-E3
# 1                         1
#
#                                            evnt2text  \
# 0  left(contexts: A former militant of the French...
# 1                                                  1
#
#                    evnt2type                              relation  \
# ...

# %%
data.loc[len(data)] = [1,2,1,2,1,1,1,1]

# %%
data.loc[len(data)] = [1,2,1,2,2,2,2,2]

# %%
r.tolist()
# Out:
# ['AFP_ENG_20100414.0615-E1',
#  'killer(contexts: French far - left killer leaves jail)',
#  'Life_Die',
#  'AFP_ENG_20100414.0615-E3',
#  'left(contexts: A former militant of the French far - left group Action Directe , Georges Cipriani , left prison on parole on Wednesday after 23 years behind bars for two high - profile murders .)',
#  'Movement_Transport-Person',
#  'EventError/    /    /    /    /    |',
#  'AFP_ENG_20030519.0372.xml']

# %%
data
# Out:
#                     evnt1id  \
# 0  AFP_ENG_20100414.0615-E1
# 1                         1
# 2                         1
#
#                                            evnt1text evnt1type  \
# 0  killer(contexts: French far - left killer leav...  Life_Die
# 1                                                  2         1
# 2                                                  2         1
#
#                     evnt2id  \
# 0  AFP_ENG_20100414.0615-E3
# 1                         2
# 2                         2
#
#                                            evnt2text  \
# 0  left(contexts: A former militant of the French...
# 1                                                  1
# 2                                                  2
#
#                    evnt2type                              relation  \
# 0  Movement_Transport-Person  EventError/    /    /    /    /    |
# 1                          1                                     1
# ...

# %%
import pandas as pd
mydata= pd.read_csv("/Users/youssrarebboud/newdata.csv", sep='\t')

# %%
mydata
# Out:
#      Unnamed: 0                    evnt1id  \
# 0             0   AFP_ENG_20100414.0615-E5
# 1             1   AFP_ENG_20100414.0615-E5
# 2             2   AFP_ENG_20100414.0615-E5
# 3             3   AFP_ENG_20100414.0615-E5
# 4             4   AFP_ENG_20100414.0615-E5
# ..          ...                        ...
# 443         443  AFP_ENG_20030509.0345-EV1
# 444         444  AFP_ENG_20030509.0345-EV1
# 445         445  AFP_ENG_20030509.0345-EV1
# 446         446  AFP_ENG_20030509.0345-EV2
# 447         447  AFP_ENG_20030509.0345-EV2
#
#                                              evnt1text  \
# 0    parole(contexts: A former militant of the Fren...
# 1    parole(contexts: A former militant of the Fren...
# 2    parole(contexts: A former militant of the Fren...
# 3    parole(contexts: A former militant of the Fren...
# 4    parole(contexts: A former militant of the Fren...
# ..                                                 ...
# ...

# %%
filter = mydata['rel1'].str.contains('Expansion')

# %%
mydata = mydata[~filter]

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Temporality.Starts/Relative/Included_Start/Includes', value='starts', regex=True)
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Temporality.Starts/Relative/Includes/Included_Start', value='starts 2', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Temporality.Starts/Relative/Included_Start/Includes', value='starts', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Temporality.Starts/Relative/Includes/Included_Start', value='starts 2', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Temporality.Starts/Relative/Included_Start/Includes', value='starts', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Temporality.Starts/Relative/Includes/Included_Start', value='starts 2', regex=True)

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Temporality.Before/Relative/Previous/After', value='immediately before', regex=True)
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Temporality.Before/Relative/After/Previous', value='immediately before 2', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Temporality.Before/Relative/Previous/After', value='immediately before', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Temporality.Before/Relative/After/Previous', value='immediately before 2', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Temporality.Before/Relative/Previous/After', value='immediately before', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Temporality.Before/Relative/After/Previous', value='immediately before 2', regex=True)

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Temporality.Meet/Relative/Previous/After', value='meets', regex=True)
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Temporality.Meet/Relative/After/Previous', value='meets 2', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Temporality.Meet/Relative/Previous/After', value='meets', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Temporality.Meet/Relative/After/Previous', value='meets 2', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Temporality.Meet/Relative/Previous/After', value='meets', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Temporality.Meet/Relative/After/Previous', value='meets 2', regex=True)

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Temporality.Finishes/Relative/Includes/Included_End', value='ends', regex=True)
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Temporality.Finishes/Relative/Included_End/Includes', value='ends 2', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Temporality.Finishes/Relative/Includes/Included_End', value='ends', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Temporality.Finishes/Relative/Included_End/Includes', value='ends 2', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Temporality.Finishes/Relative/Includes/Included_End', value='ends', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Temporality.Finishes/Relative/Included_End/Includes', value='ends 2', regex=True)

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Temporality.During/Relative/Includes/Included_IN', value='contains', regex=True)
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Temporality.During/Relative/Included_IN/Includes', value='contains 2', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Temporality.During/Relative/Includes/Included_IN', value='contains', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Temporality.During/Relative/Included_IN/Includes', value='contains 2', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Temporality.During/Relative/Includes/Included_IN', value='contains', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Temporality.During/Relative/Included_IN/Includes', value='contains 2', regex=True)

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Temporality.equals/    /    /', value='simoultaneous to', regex=True)

mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Temporality.equals/    /    /', value='simoultaneous to', regex=True)

mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Temporality.equals/    /    /', value='simoultaneous to', regex=True)

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Contingency.Causality/Absolute/Cause/Result', value='causes', regex=True)
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Contingency.Causality/Absolute/Result/Cause', value='causes 2', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Contingency.Causality/Absolute/Cause/Result', value='causes', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Contingency.Causality/Absolute/Result/Cause', value='causes 2', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Contingency.Causality/Absolute/Cause/Result', value='causes', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Contingency.Causality/Absolute/Result/Cause', value='causes 2', regex=True)

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Contingency.Causality/Relative/Cause/Result', value='causes', regex=True)
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Contingency.Causality/Relative/Result/Cause', value='causes 2', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Contingency.Causality/Relative/Cause/Result', value='causes', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Contingency.Causality/Relative/Result/Cause', value='causes 2', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Contingency.Causality/Relative/Cause/Result', value='causes', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Contingency.Causality/Relative/Result/Cause', value='causes 2', regex=True)

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Contingency.Causality/Relative/Cause/Result', value='causes', regex=True)
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Contingency.Causality/Relative/Result/Cause', value='causes 2', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Contingency.Causality/Relative/Cause/Result', value='causes', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Contingency.Causality/Relative/Result/Cause', value='causes 2', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Contingency.Causality/Relative/Cause/Result', value='causes', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Contingency.Causality/Relative/Result/Cause', value='causes 2', regex=True)

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Contingency.Conditionlity/Relative/Emergence/Condition', value='enables', regex=True)
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Contingency.Conditionlity/Relative/Condition/Emergence', value='enables 2', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Contingency.Conditionlity/Relative/Emergence/Condition', value='enables', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Contingency.Conditionlity/Relative/Condition/Emergence', value='enables 2', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Contingency.Conditionlity/Relative/Emergence/Condition', value='enables', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Contingency.Conditionlity/Relative/Condition/Emergence', value='enables 2', regex=True)

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Comparison.Opposite/Absolute/    /    ', value='opposite to', regex=True)
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Comparison.Opposite/Absolute/Opposite/Opposite', value='opposite to 2', regex=True)

mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Comparison.Opposite/Absolute/    /    ', value='opposite to', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Comparison.Opposite/Absolute/Opposite/Opposite', value='opposite to 2', regex=True)

mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Comparison.Opposite/Absolute/    /    ', value='opposite to', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Comparison.Opposite/Absolute/Opposite/Opposite', value='opposite to 2', regex=True)

# %%
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Comparison.Negation/Relative/Negation/Initiator', value='alternative to', regex=True)
mydata['rel1'] = mydata['rel1'].replace(to_replace='True/Related/Comparison.Negation/Relative/Initiator/Negation', value='alternative to 2', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Comparison.Negation/Relative/Negation/Initiator', value='alternative to', regex=True)
mydata['rel2'] = mydata['rel2'].replace(to_replace='True/Related/Comparison.Negation/Relative/Initiator/Negation', value='alternative to 2', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Comparison.Negation/Relative/Negation/Initiator', value='alternative to', regex=True)
mydata['rel3'] = mydata['rel3'].replace(to_replace='True/Related/Comparison.Negation/Relative/Initiator/Negation', value='alternative to 2', regex=True)

# %%
mydata
# Out:
#      Unnamed: 0                    evnt1id  \
# 0             0   AFP_ENG_20100414.0615-E5
# 1             1   AFP_ENG_20100414.0615-E5
# 2             2   AFP_ENG_20100414.0615-E5
# 3             3   AFP_ENG_20100414.0615-E5
# 4             4   AFP_ENG_20100414.0615-E5
# ..          ...                        ...
# 443         443  AFP_ENG_20030509.0345-EV1
# 444         444  AFP_ENG_20030509.0345-EV1
# 445         445  AFP_ENG_20030509.0345-EV1
# 446         446  AFP_ENG_20030509.0345-EV2
# 447         447  AFP_ENG_20030509.0345-EV2
#
#                                              evnt1text  \
# 0    parole(contexts: A former militant of the Fren...
# 1    parole(contexts: A former militant of the Fren...
# 2    parole(contexts: A former militant of the Fren...
# 3    parole(contexts: A former militant of the Fren...
# 4    parole(contexts: A former militant of the Fren...
# ..                                                 ...
# ...

# %%
mydata.to_csv('mapped_data.csv', sep='\t')

# %%
mydata
# Out:
#      Unnamed: 0                    evnt1id  \
# 0             0   AFP_ENG_20100414.0615-E5
# 1             1   AFP_ENG_20100414.0615-E5
# 2             2   AFP_ENG_20100414.0615-E5
# 3             3   AFP_ENG_20100414.0615-E5
# 4             4   AFP_ENG_20100414.0615-E5
# ..          ...                        ...
# 443         443  AFP_ENG_20030509.0345-EV1
# 444         444  AFP_ENG_20030509.0345-EV1
# 445         445  AFP_ENG_20030509.0345-EV1
# 446         446  AFP_ENG_20030509.0345-EV2
# 447         447  AFP_ENG_20030509.0345-EV2
#
#                                              evnt1text  \
# 0    parole(contexts: A former militant of the Fren...
# 1    parole(contexts: A former militant of the Fren...
# 2    parole(contexts: A former militant of the Fren...
# 3    parole(contexts: A former militant of the Fren...
# 4    parole(contexts: A former militant of the Fren...
# ..                                                 ...
# ...

# %%
file=pd.read_csv('mapped_data.csv', sep='\t')

# %%
file['rel1']
# Out:
# 0                                                meets 2
# 1                                   immediately before 2
# 2                                               starts 2
# 3                                   immediately before 2
# 4                                   immediately before 2
#                              ...
# 443                                              meets 2
# 444                                              enables
# 445    True/Related/Expansion.Conjunction/Relative/Ge...
# 446    True/Related/Inheritance.Subevent/Relative/Des...
# 447                                            enables 2
# Name: rel1, Length: 448, dtype: object
